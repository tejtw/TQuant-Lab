# %%
import os 

StockList1 = ['1227', '1234', '1304', '1314', '1434', '1440', '1476', '1504', '1507', '1590', '1605', '1704', '1710', '1717', '1723', '1789',
 '1802', '1907', '2006', '2015', '2049', '2101', '2103', '2106', '2204', '2227', '2327', '2337', '2344', '2356', '2360', '2362',
 '2379', '2384', '2385', '2392', '2395', '2448', '2449', '2450', '2451', '2489', '2501', '2504', '2511', '2542', '2545', '2548',
 '2603', '2606', '2607', '2608', '2609', '2610', '2615', '2618', '2707', '2723', '2727', '2809', '2812', '2823', '2834', '2845',
 '2847', '2855', '2884', '2887', '2888', '2889', '2903', '2915', '3034', '3037', '3044', '3149', '3189', '3406', '3702', '4938',
 '4958', '5522', '5871', '6005', '6176', '6239', '6269', '6286', '8008', '8046', '8078', '8422', '9904', '9907', '9914', '9917', '9921',
 '9933', '9940', '9945', '2458', '5264', '2206', '1201', '2347', '3231', '5534', '6116', '9910', '1477', '2353', '6271', '1319',
 '1722', '2059', '3060', '3474', '3673', '2393', '2376', '2439', '3682', '1262', '2201', '2377', '3576', '2352', '2838', '8150',
 '2324', '2231', '8454', '2833', '6285', '6409', '1536', '1702', '2313', '2498', '2867', '6415', '6456', '9938', '2383', '4137', '6452',
 '1707', '1589', '2849', '6414', '8464', '2355', '2345', '3706', '2023', '2371', '1909', '2633', '3532', '9941', '2492', '3019',
 '3443', '4915', '4943', '1229', '2441', '2027', '3026', '1210', '2104', '2456', '5269', '8341', '2354', '3005', '3481', '6669',
 '2409', '3023', '6213', '2404', '3533', '6278', '6592', '3653', '3661', '3665', '2301', '3714', '2883', '2890', '6531', '1904',
 '2014', '2105', '2108', '2474', '2637', '6781', '1102', '4919', '1402', '3035', '3036', '4961', '6719', '6770', '2368', '1795',
 '6550', '6789', '3017', '1101', '1216', '1301', '1303', '1326', '2002', '2207', '2303', '2308', '2311', '2317', '2325', '2330',
 '2357', '2382', '2412', '2454', '2801', '2880', '2881', '2882', '2885', '2886', '2891', '2892', '2912', '3008', '3045', '3697',
 '4904', '5880', '6505', '2408', '3711', '5876']

tickers = " ".join(StockList1)

os.environ['TEJAPI_BASE'] = 'https://api.tej.com.tw'
os.environ['TEJAPI_KEY'] = 'your_key'

os.environ['mdate'] = '20170101 20230726'
os.environ['ticker'] = tickers

# !zipline ingest -b tquant

from zipline.pipeline import Pipeline
from zipline.TQresearch.tej_pipeline import run_pipeline
from zipline.pipeline.data import TWEquityPricing
from zipline.pipeline.factors import SimpleMovingAverage
# Out:
# [2023-10-25 10:09:05.344084] INFO: zipline.data.bundles.core: Ingesting tquant.
# Merging daily equity files:

# %% [markdown]
# ## Filters
# Filters 是一個將資產在某個時間點的特徵轉換為**布林值**的函數 ：
#
# ```
# F(asset, timestamp) -> boolean
# ```
# **在 Pipeline 中，Filters 用於縮小股票池的大小**，這裡有兩種 `Filter` 常見的創建方式：使用 `Factor`／ `Classifier` 方法或使用比較運算子（comparison operators）。
#
# ### Comparison Operators
# 對 `Factors` 和 `Classifier` 使用比較運算子就可以創建 Filters。
#
# 有鑒於我們尚未介紹到 `Classifier`，我們僅使用 `Factors` 舉例，下方的範例建立了一個當最近一期收盤價大於 $20 時會返回 `True` 的 filter 。

# %%
last_close_price = TWEquityPricing.close.latest
close_price_filter = last_close_price > 20

# %% [markdown]
# 而以下這個範例建立一個新的 filter，只要近 10 天收盤價平均值低於近 30 天收盤價平均值，該過濾器就會返回 True。

# %%
mean_close_10 = SimpleMovingAverage(inputs=[TWEquityPricing.close], window_length=10)
mean_close_30 = SimpleMovingAverage(inputs=[TWEquityPricing.close], window_length=30)
mean_crossover_filter = mean_close_10 < mean_close_30

# %% [markdown]
# 記住，在每天中每檔證券都會擁有自己的 `True` 或 `False` 值。

# %% [markdown]
# ### Factor／Classifier Methods
# 很多種 `Factor` 和 `Classifier` 都會回傳 `Filters`。
#
# 但同樣地，由於我們尚未討論到 `Classifier`，目前我們僅使用 `Factor`（稍後我們會討論 `Classifier`）。
#
# `Factor.top(n)`會建立一個 `Filter` ，當排名在指定 `Factor` 前 `n` 名證券，會標記為 `True` ，其餘標記為 `False`。
#
# 下面的範例建立了一個會每天將最近一期收盤價排名前30名的證券標示為`True` 的filter。

# %%
last_close_price = TWEquityPricing.close.latest
top_close_price_filter = last_close_price.top(30)

# %% [markdown]
# ## Dollar Volume Filter
# 作為第一個範例，我們創建一個 Filter 。如果該證券過去 30 日平均交易量大於 $1, 000,000, 000 則回傳 `True` 值。
#
# 為了實現這個效果，我們首先需要創建一個 `AverageDollarVolume` factor 以計算過去 30 日平均交易量。讓我們匯入 __built-in factor__ `AverageDollarVolume`。

# %%
from zipline.pipeline.factors import AverageDollarVolume

# %% [markdown]
# 接著，讓我們實例化 `AverageDollarVolume` factor。

# %%
dollar_volume = AverageDollarVolume(window_length=30)

# %% [markdown]
# 在預設情況下， `AverageDollarVolume` 會使用 `TWEquityPricing.close` 與 `TWEquityPricing.volume` 作為 `inputs`，所以我們不須去定義他們。

# %% [markdown]
# 現在我們有了平均交易量 factor ，我們可以以布林值表達式創建 filter。下方程式創建了一個當證券的平均成交量 `dollar_volume` 大於 $1, 000,000, 000 時會回傳 `True` 的 filter。

# %%
high_dollar_volume = (dollar_volume > 1000000000)

# %% [markdown]
# 為了知道 fitler 的實際結果，我們將它作為一個欄位加入先前課程中創立的 pipeline 中。此外，如同在 [lecture/Factors](https://github.com/tejtw/TQuant-Lab/blob/main/lecture/Factors.ipynb) 中所介紹的，我們額外加入了`percent_difference`。

# %%
def make_pipeline():

    mean_close_10 = SimpleMovingAverage(inputs=[TWEquityPricing.close], window_length=10)
    mean_close_30 = SimpleMovingAverage(inputs=[TWEquityPricing.close], window_length=30)

    percent_difference = (mean_close_10 - mean_close_30) / mean_close_30
    
    dollar_volume = AverageDollarVolume(window_length=30)
    high_dollar_volume = (dollar_volume > 1000000000)

    return Pipeline(
        columns={
            'percent_difference': percent_difference,            
            'high_dollar_volume': high_dollar_volume
        }
    )

# %% [markdown]
# 如果我們執行 pipeline ，就會產出 `high_dollar_volume` 欄位，當 filter 條件成立時會回傳布林值 `True`。

# %%
result = run_pipeline(make_pipeline(), '2023-03-03', '2023-06-01')
result.loc['2023-03-03']
# Out:
#                                               percent_difference  \
# 2023-03-03 00:00:00+00:00 Equity(0 [1101])              0.037521
#                           Equity(1 [1102])              0.023348
#                           Equity(2 [1201])              0.033230
#                           Equity(3 [1210])              0.034966
#                           Equity(4 [1216])             -0.002188
#                           Equity(5 [1227])              0.006018
#                           Equity(6 [1229])              0.016744
#                           Equity(7 [1234])              0.032952
#                           Equity(9 [1301])              0.012596
#                           Equity(10 [1303])             0.006129
#                           Equity(11 [1304])             0.029785
#                           Equity(12 [1314])             0.009970
#                           Equity(13 [1319])            -0.001178
#                           Equity(14 [1326])            -0.005814
#                           Equity(15 [1402])            -0.004791
#                           Equity(16 [1434])             0.006240
#                           Equity(17 [1440])             0.025419
#                           Equity(18 [1476])            -0.005495
#                           Equity(19 [1477])            -0.018088
#                           Equity(20 [1504])             0.035845
#                           Equity(22 [1536])             0.017208
#                           Equity(23 [1589])             0.044450
#                           Equity(24 [1590])             0.031887
#                           Equity(25 [1605])             0.060100
#                           Equity(26 [1702])             0.009178
#                           Equity(28 [1707])             0.037891
#                           Equity(29 [1710])             0.003375
#                           Equity(30 [1717])            -0.003197
#                           Equity(31 [1722])             0.022813
#                           Equity(32 [1723])             0.019360
#                           Equity(33 [1789])             0.003396
#                           Equity(34 [1795])             0.074224
#                           Equity(35 [1802])             0.012429
#                           Equity(36 [1904])             0.000874
#                           Equity(37 [1907])             0.019787
#                           Equity(38 [1909])             0.027745
#                           Equity(39 [2002])             0.004466
#                           Equity(40 [2006])             0.025254
#                           Equity(41 [2014])             0.014204
#                           Equity(42 [2015])             0.034428
#                           Equity(43 [2023])             0.018693
#                           Equity(44 [2027])            -0.008330
#                           Equity(45 [2049])             0.078031
#                           Equity(46 [2059])             0.007570
#                           Equity(47 [2101])             0.041074
#                           Equity(48 [2103])             0.014035
#                           Equity(49 [2104])             0.017730
#                           Equity(50 [2105])             0.000775
#                           Equity(51 [2106])             0.009438
#                           Equity(52 [2108])             0.036776
#                           Equity(53 [2201])             0.049502
#                           Equity(54 [2204])             0.010645
#                           Equity(55 [2206])             0.077871
#                           Equity(56 [2207])            -0.017813
#                           Equity(57 [2227])             0.010774
#                           Equity(58 [2231])             0.042965
#                           Equity(59 [2301])             0.026942
#                           Equity(60 [2303])             0.034036
#                           Equity(61 [2308])             0.007811
#                           Equity(63 [2313])             0.012800
#                           Equity(64 [2317])             0.018607
#                           Equity(65 [2324])             0.019683
#                           Equity(67 [2327])             0.030150
#                           Equity(68 [2330])             0.001321
#                           Equity(69 [2337])            -0.015398
#                           Equity(70 [2344])             0.042531
#                           Equity(71 [2345])             0.057284
#                           Equity(72 [2347])             0.021927
#                           Equity(73 [2352])             0.028949
#                           Equity(74 [2353])             0.023762
#                           Equity(75 [2354])             0.011568
#                           Equity(76 [2355])             0.004033
#                           Equity(77 [2356])             0.019233
#                           Equity(78 [2357])             0.012723
#                           Equity(79 [2360])             0.002825
#                           Equity(80 [2362])             0.011710
#                           Equity(81 [2368])             0.000263
#                           Equity(82 [2371])             0.000937
#                           Equity(83 [2376])             0.015819
#                           Equity(84 [2377])             0.034247
#                           Equity(85 [2379])             0.070902
#                           Equity(86 [2382])             0.034102
#                           Equity(87 [2383])             0.015165
#                           Equity(88 [2385])             0.025321
#                           Equity(89 [2392])             0.020735
#                           Equity(90 [2393])             0.016409
#                           Equity(91 [2395])             0.013429
#                           Equity(92 [2404])             0.059047
#                           Equity(93 [2408])             0.013351
#                           Equity(94 [2409])             0.070116
#                           Equity(95 [2412])             0.007754
#                           Equity(96 [2439])             0.025335
#                           Equity(97 [2441])             0.024049
#                           Equity(99 [2449])             0.043539
#                           Equity(100 [2450])            0.028005
#                           Equity(101 [2451])            0.016709
#                           Equity(102 [2454])            0.014696
#                           Equity(104 [2458])            0.044017
#                           Equity(105 [2474])            0.026975
#                           Equity(106 [2489])            0.031302
#                           Equity(107 [2492])            0.053220
#                           Equity(108 [2498])            0.036708
#                           Equity(109 [2501])            0.020634
#                           Equity(110 [2504])            0.030064
#                           Equity(111 [2511])            0.010615
#                           Equity(112 [2542])            0.015768
#                           Equity(113 [2545])            0.036225
#                           Equity(114 [2548])            0.013438
#                           Equity(115 [2603])            0.001640
#                           Equity(116 [2606])            0.052917
#                           Equity(117 [2607])            0.013308
#                           Equity(118 [2608])           -0.010798
#                           Equity(119 [2609])            0.004344
#                           Equity(120 [2610])            0.043368
#                           Equity(121 [2615])            0.004935
#                           Equity(122 [2618])           -0.000347
#                           Equity(123 [2633])            0.003666
#                           Equity(124 [2637])            0.033013
#                           Equity(125 [2707])            0.096379
#                           Equity(126 [2723])            0.045697
#                           Equity(127 [2727])            0.241944
#                           Equity(128 [2801])           -0.000478
#                           Equity(129 [2809])           -0.011668
#                           Equity(130 [2812])            0.018113
#                           Equity(132 [2834])            0.038758
#                           Equity(133 [2838])            0.005866
#                           Equity(134 [2845])            0.007846
#                           Equity(135 [2849])           -0.003272
#                           Equity(136 [2855])            0.022836
#                           Equity(137 [2867])           -0.008540
#                           Equity(138 [2880])           -0.001165
#                           Equity(139 [2881])            0.003972
#                           Equity(140 [2882])            0.015239
#                           Equity(141 [2883])            0.005738
#                           Equity(142 [2884])            0.014164
#                           Equity(143 [2885])            0.001544
#                           Equity(144 [2886])            0.027941
#                           Equity(145 [2887])            0.017232
#                           Equity(146 [2888])           -0.006500
#                           Equity(147 [2889])            0.011884
#                           Equity(148 [2890])            0.000297
#                           Equity(149 [2891])           -0.000440
#                           Equity(150 [2892])            0.004836
#                           Equity(151 [2903])            0.014507
#                           Equity(152 [2912])           -0.006737
#                           Equity(153 [2915])            0.018087
#                           Equity(154 [3005])            0.040516
#                           Equity(155 [3008])            0.008678
#                           Equity(156 [3017])            0.041935
#                           Equity(157 [3019])            0.010214
#                           Equity(158 [3023])            0.009741
#                           Equity(159 [3026])            0.022856
#                           Equity(160 [3034])            0.084553
#                           Equity(161 [3035])            0.056630
#                           Equity(162 [3036])            0.014747
#                           Equity(163 [3037])            0.019296
#                           Equity(164 [3044])            0.017785
#                           Equity(165 [3045])            0.005446
#                           Equity(166 [3060])            0.030530
#                           Equity(167 [3149])           -0.002408
#                           Equity(168 [3189])            0.006528
#                           Equity(169 [3231])            0.021629
#                           Equity(170 [3406])            0.048623
#                           Equity(171 [3443])            0.200979
#                           Equity(172 [3481])            0.116559
#                           Equity(173 [3532])           -0.003375
#                           Equity(174 [3533])            0.018689
#                           Equity(175 [3576])            0.003844
#                           Equity(176 [3653])            0.010785
#                           Equity(177 [3661])            0.039343
#                           Equity(178 [3665])            0.047351
#                           Equity(179 [3673])            0.050024
#                           Equity(180 [3682])            0.005981
#                           Equity(181 [3702])            0.010747
#                           Equity(182 [3706])            0.002501
#                           Equity(183 [3711])            0.009755
#                           Equity(184 [3714])           -0.005816
#                           Equity(185 [4137])            0.037455
#                           Equity(186 [4904])            0.015176
#                           Equity(187 [4915])            0.018338
#                           Equity(188 [4919])            0.046445
#                           Equity(189 [4938])            0.024924
#                           Equity(190 [4943])           -0.036962
#                           Equity(191 [4958])            0.024270
#                           Equity(192 [4961])            0.116186
#                           Equity(194 [5269])            0.061588
#                           Equity(195 [5522])            0.012160
#                           Equity(196 [5534])            0.014493
#                           Equity(197 [5871])           -0.003119
#                           Equity(198 [5876])            0.009899
#                           Equity(199 [5880])           -0.000376
#                           Equity(200 [6005])            0.016797
#                           Equity(201 [6116])            0.049125
#                           Equity(202 [6176])            0.021422
#                           Equity(203 [6213])           -0.006653
#                           Equity(204 [6239])            0.024507
#                           Equity(205 [6269])           -0.015816
#                           Equity(206 [6271])            0.007304
#                           Equity(207 [6278])           -0.016267
#                           Equity(208 [6285])            0.016290
#                           Equity(209 [6409])            0.008817
#                           Equity(210 [6414])            0.023087
#                           Equity(211 [6415])            0.022885
#                           Equity(213 [6456])            0.013724
#                           Equity(214 [6505])            0.013181
#                           Equity(215 [6531])            0.153928
#                           Equity(216 [6550])            0.011722
#                           Equity(217 [6592])            0.024005
#                           Equity(218 [6669])            0.061960
#                           Equity(219 [6719])           -0.004284
#                           Equity(220 [6770])           -0.008743
#                           Equity(221 [6781])            0.042214
#                           Equity(222 [6789])            0.014090
#                           Equity(223 [8046])            0.009388
#                           Equity(224 [8150])            0.028319
#                           Equity(225 [8341])           -0.003402
#                           Equity(226 [8422])            0.018256
#                           Equity(227 [8454])            0.010619
#                           Equity(228 [8464])            0.028226
#                           Equity(229 [9904])           -0.000246
#                           Equity(230 [9907])            0.000190
#                           Equity(231 [9910])           -0.051230
#                           Equity(232 [9914])           -0.008447
#                           Equity(233 [9917])            0.001662
#                           Equity(234 [9921])           -0.002739
#                           Equity(235 [9933])            0.015381
#                           Equity(236 [9938])            0.027505
#                           Equity(237 [9940])            0.021334
#                           Equity(238 [9941])            0.013461
#                           Equity(239 [9945])           -0.001735
#
#                                               high_dollar_volume
# 2023-03-03 00:00:00+00:00 Equity(0 [1101])                 False
#                           Equity(1 [1102])                 False
#                           Equity(2 [1201])                 False
#                           Equity(3 [1210])                 False
#                           Equity(4 [1216])                 False
#                           Equity(5 [1227])                 False
#                           Equity(6 [1229])                 False
#                           Equity(7 [1234])                 False
#                           Equity(9 [1301])                 False
#                           Equity(10 [1303])                False
#                           Equity(11 [1304])                False
#                           Equity(12 [1314])                False
#                           Equity(13 [1319])                False
#                           Equity(14 [1326])                False
#                           Equity(15 [1402])                False
#                           Equity(16 [1434])                False
#                           Equity(17 [1440])                False
#                           Equity(18 [1476])                False
#                           Equity(19 [1477])                False
#                           Equity(20 [1504])                False
#                           Equity(22 [1536])                False
#                           Equity(23 [1589])                False
#                           Equity(24 [1590])                False
#                           Equity(25 [1605])                 True
#                           Equity(26 [1702])                False
#                           Equity(28 [1707])                False
#                           Equity(29 [1710])                False
#                           Equity(30 [1717])                False
#                           Equity(31 [1722])                False
#                           Equity(32 [1723])                False
#                           Equity(33 [1789])                False
#                           Equity(34 [1795])                 True
#                           Equity(35 [1802])                False
#                           Equity(36 [1904])                False
#                           Equity(37 [1907])                False
#                           Equity(38 [1909])                False
#                           Equity(39 [2002])                False
#                           Equity(40 [2006])                False
#                           Equity(41 [2014])                False
#                           Equity(42 [2015])                False
#                           Equity(43 [2023])                False
#                           Equity(44 [2027])                False
#                           Equity(45 [2049])                False
#                           Equity(46 [2059])                False
#                           Equity(47 [2101])                False
#                           Equity(48 [2103])                False
#                           Equity(49 [2104])                False
#                           Equity(50 [2105])                False
#                           Equity(51 [2106])                False
#                           Equity(52 [2108])                False
#                           Equity(53 [2201])                 True
#                           Equity(54 [2204])                False
#                           Equity(55 [2206])                False
#                           Equity(56 [2207])                False
#                           Equity(57 [2227])                False
#                           Equity(58 [2231])                False
#                           Equity(59 [2301])                False
#                           Equity(60 [2303])                 True
#                           Equity(61 [2308])                 True
#                           Equity(63 [2313])                False
#                           Equity(64 [2317])                 True
#                           Equity(65 [2324])                False
#                           Equity(67 [2327])                 True
#                           Equity(68 [2330])                 True
#                           Equity(69 [2337])                False
#                           Equity(70 [2344])                False
#                           Equity(71 [2345])                False
#                           Equity(72 [2347])                False
#                           Equity(73 [2352])                False
#                           Equity(74 [2353])                False
#                           Equity(75 [2354])                False
#                           Equity(76 [2355])                False
#                           Equity(77 [2356])                False
#                           Equity(78 [2357])                False
#                           Equity(79 [2360])                False
#                           Equity(80 [2362])                False
#                           Equity(81 [2368])                False
#                           Equity(82 [2371])                False
#                           Equity(83 [2376])                False
#                           Equity(84 [2377])                False
#                           Equity(85 [2379])                 True
#                           Equity(86 [2382])                False
#                           Equity(87 [2383])                False
#                           Equity(88 [2385])                False
#                           Equity(89 [2392])                False
#                           Equity(90 [2393])                False
#                           Equity(91 [2395])                False
#                           Equity(92 [2404])                False
#                           Equity(93 [2408])                False
#                           Equity(94 [2409])                False
#                           Equity(95 [2412])                 True
#                           Equity(96 [2439])                False
#                           Equity(97 [2441])                False
#                           Equity(99 [2449])                False
#                           Equity(100 [2450])               False
#                           Equity(101 [2451])               False
#                           Equity(102 [2454])                True
#                           Equity(104 [2458])               False
#                           Equity(105 [2474])               False
#                           Equity(106 [2489])               False
#                           Equity(107 [2492])               False
#                           Equity(108 [2498])                True
#                           Equity(109 [2501])               False
#                           Equity(110 [2504])               False
#                           Equity(111 [2511])               False
#                           Equity(112 [2542])               False
#                           Equity(113 [2545])               False
#                           Equity(114 [2548])               False
#                           Equity(115 [2603])                True
#                           Equity(116 [2606])               False
#                           Equity(117 [2607])               False
#                           Equity(118 [2608])               False
#                           Equity(119 [2609])                True
#                           Equity(120 [2610])                True
#                           Equity(121 [2615])                True
#                           Equity(122 [2618])                True
#                           Equity(123 [2633])               False
#                           Equity(124 [2637])               False
#                           Equity(125 [2707])               False
#                           Equity(126 [2723])               False
#                           Equity(127 [2727])                True
#                           Equity(128 [2801])               False
#                           Equity(129 [2809])               False
#                           Equity(130 [2812])               False
#                           Equity(132 [2834])               False
#                           Equity(133 [2838])               False
#                           Equity(134 [2845])               False
#                           Equity(135 [2849])               False
#                           Equity(136 [2855])               False
#                           Equity(137 [2867])               False
#                           Equity(138 [2880])               False
#                           Equity(139 [2881])               False
#                           Equity(140 [2882])                True
#                           Equity(141 [2883])               False
#                           Equity(142 [2884])               False
#                           Equity(143 [2885])               False
#                           Equity(144 [2886])               False
#                           Equity(145 [2887])               False
#                           Equity(146 [2888])               False
#                           Equity(147 [2889])               False
#                           Equity(148 [2890])               False
#                           Equity(149 [2891])               False
#                           Equity(150 [2892])               False
#                           Equity(151 [2903])               False
#                           Equity(152 [2912])               False
#                           Equity(153 [2915])               False
#                           Equity(154 [3005])               False
#                           Equity(155 [3008])                True
#                           Equity(156 [3017])               False
#                           Equity(157 [3019])               False
#                           Equity(158 [3023])               False
#                           Equity(159 [3026])               False
#                           Equity(160 [3034])                True
#                           Equity(161 [3035])                True
#                           Equity(162 [3036])               False
#                           Equity(163 [3037])                True
#                           Equity(164 [3044])               False
#                           Equity(165 [3045])               False
#                           Equity(166 [3060])               False
#                           Equity(167 [3149])               False
#                           Equity(168 [3189])               False
#                           Equity(169 [3231])               False
#                           Equity(170 [3406])               False
#                           Equity(171 [3443])                True
#                           Equity(172 [3481])                True
#                           Equity(173 [3532])               False
#                           Equity(174 [3533])               False
#                           Equity(175 [3576])               False
#                           Equity(176 [3653])               False
#                           Equity(177 [3661])                True
#                           Equity(178 [3665])               False
#                           Equity(179 [3673])               False
#                           Equity(180 [3682])               False
#                           Equity(181 [3702])               False
#                           Equity(182 [3706])               False
#                           Equity(183 [3711])                True
#                           Equity(184 [3714])               False
#                           Equity(185 [4137])               False
#                           Equity(186 [4904])               False
#                           Equity(187 [4915])               False
#                           Equity(188 [4919])                True
#                           Equity(189 [4938])               False
#                           Equity(190 [4943])               False
#                           Equity(191 [4958])               False
#                           Equity(192 [4961])                True
#                           Equity(194 [5269])               False
#                           Equity(195 [5522])               False
#                           Equity(196 [5534])               False
#                           Equity(197 [5871])                True
#                           Equity(198 [5876])               False
#                           Equity(199 [5880])               False
#                           Equity(200 [6005])               False
#                           Equity(201 [6116])               False
#                           Equity(202 [6176])               False
#                           Equity(203 [6213])               False
#                           Equity(204 [6239])               False
#                           Equity(205 [6269])               False
#                           Equity(206 [6271])               False
#                           Equity(207 [6278])               False
#                           Equity(208 [6285])               False
#                           Equity(209 [6409])               False
#                           Equity(210 [6414])               False
#                           Equity(211 [6415])                True
#                           Equity(213 [6456])               False
#                           Equity(214 [6505])               False
#                           Equity(215 [6531])                True
#                           Equity(216 [6550])               False
#                           Equity(217 [6592])               False
#                           Equity(218 [6669])                True
#                           Equity(219 [6719])                True
#                           Equity(220 [6770])               False
#                           Equity(221 [6781])               False
#                           Equity(222 [6789])               False
#                           Equity(223 [8046])                True
#                           Equity(224 [8150])               False
#                           Equity(225 [8341])               False
#                           Equity(226 [8422])               False
#                           Equity(227 [8454])               False
#                           Equity(228 [8464])               False
#                           Equity(229 [9904])               False
#                           Equity(230 [9907])               False
#                           Equity(231 [9910])               False
#                           Equity(232 [9914])               False
#                           Equity(233 [9917])               False
#                           Equity(234 [9921])               False
#                           Equity(235 [9933])               False
#                           Equity(236 [9938])               False
#                           Equity(237 [9940])               False
#                           Equity(238 [9941])               False
#                           Equity(239 [9945])               False

# %% [markdown]
# ## Applying a Screen
# 在預設情況下，pipeline 每日會針對每個在 bundle 中的資產生成一筆資料。
#
# 但很多時候，我們只關注那些**符合特定條件的證券**（例如，為了能快速成交，我們可能只會關注那些每日交易量足夠大的證券）。我們可以透過 `screen` 告訴 pipeline 去忽略那些 filter 回傳的布林值為 `False` 的證券。
#
# 為了讓 pipeline 過濾出那些**30日平均交易量**大於 $1, 000,000, 000 的證券，我們可以簡單的將 `high_dollar_volume` filter 作為 `screen` 的參數。
#
# 現在我們的 pipeline 應該會長這樣：

# %%
def make_pipeline():

    mean_close_10 = SimpleMovingAverage(inputs=[TWEquityPricing.close], window_length=10)
    mean_close_30 = SimpleMovingAverage(inputs=[TWEquityPricing.close], window_length=30)

    percent_difference = (mean_close_10 - mean_close_30) / mean_close_30
    
    dollar_volume = AverageDollarVolume(window_length=30)
    high_dollar_volume = (dollar_volume > 1000000000)

    return Pipeline(
        columns={
            'percent_difference': percent_difference
        },
        screen=high_dollar_volume
    )

# %% [markdown]
# 當我們執行程式時，pipeline 的輸出僅僅只會包含那些在特定日子滿足 `high_dollar_volume` filter 的證券。

# %%
result = run_pipeline(make_pipeline(), '2023-03-03', '2023-03-03')
print('通過 filter 的證券數: %d' % len(result))
result
# Out:
# 通過 filter 的證券數: 35
#                                               percent_difference
# 2023-03-03 00:00:00+00:00 Equity(25 [1605])             0.060100
#                           Equity(34 [1795])             0.074224
#                           Equity(53 [2201])             0.049502
#                           Equity(60 [2303])             0.034036
#                           Equity(61 [2308])             0.007811
#                           Equity(64 [2317])             0.018607
#                           Equity(67 [2327])             0.030150
#                           Equity(68 [2330])             0.001321
#                           Equity(85 [2379])             0.070902
#                           Equity(95 [2412])             0.007754
#                           Equity(102 [2454])            0.014696
#                           Equity(108 [2498])            0.036708
#                           Equity(115 [2603])            0.001640
#                           Equity(119 [2609])            0.004344
#                           Equity(120 [2610])            0.043368
#                           Equity(121 [2615])            0.004935
#                           Equity(122 [2618])           -0.000347
#                           Equity(127 [2727])            0.241944
#                           Equity(140 [2882])            0.015239
#                           Equity(155 [3008])            0.008678
#                           Equity(160 [3034])            0.084553
#                           Equity(161 [3035])            0.056630
#                           Equity(163 [3037])            0.019296
#                           Equity(171 [3443])            0.200979
#                           Equity(172 [3481])            0.116559
#                           Equity(177 [3661])            0.039343
#                           Equity(183 [3711])            0.009755
#                           Equity(188 [4919])            0.046445
#                           Equity(192 [4961])            0.116186
#                           Equity(197 [5871])           -0.003119
#                           Equity(211 [6415])            0.022885
#                           Equity(215 [6531])            0.153928
#                           Equity(218 [6669])            0.061960
#                           Equity(219 [6719])           -0.004284
#                           Equity(223 [8046])            0.009388

# %% [markdown]
# ## Inverting a Filter
# `~` 運算符是用於反轉 filter 的，將所有 `True` 轉變為 `False`，反之亦然。例如，我們可以撰寫下列的 filter 去過濾出低交易量的證券。

# %%
low_dollar_volume = ~high_dollar_volume

# %% [markdown]
# 這會對過去 30 天內所有平均交易量低於或等於 $1,000,000,000 的證券回傳 `True`。

# %% [markdown]
# 其餘 __built-in filters__ 請參考：[Pipeline built-in filters.ipynb](https://github.com/tejtw/TQuant-Lab/blob/main/lecture/Pipeline%20built-in%20filters.ipynb)
